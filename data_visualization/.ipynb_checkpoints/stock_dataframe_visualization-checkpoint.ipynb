# %%
import pandas as pd
from src.helper_functions import Globals
import matplotlib
import asyncio
from codetiming import Timer
from src.helper_functions import AsyncAPIFunctions, ExcelOperations, TradesOverview
from src.technical_analysis import TradeTechnicalRequests
import matplotlib.pyplot as plt

# %%
# async def main():
#     ...
try:
    loop = asyncio.get_running_loop()
except RuntimeError:  # 'RuntimeError: There is no current event loop...'
    loop = None
if loop and loop.is_running():
    print('Async event loop already running. Adding coroutine to the event loop.')
    tsk = loop.create_task(main())
    # ^-- https://docs.python.org/3/library/asyncio-task.html#task-object
    # Optionally, a callback function can be executed when the coroutine completes
    tsk.add_done_callback(
        lambda t: print(f'Task done with result={t.result()}  << return val of main()'))
else:
    print('Starting new event loop')
    asyncio.run(main())
# Out:
# Async event loop already running. Adding coroutine to the event loop.
# start process
# now get trades
# C:\Program Files\Python311\Lib\xml\etree\ElementTree.py:1647: RuntimeWarning: coroutine 'main' was never awaited
#   return self.target.start(tag, attrib)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task done with result=[None, None, None, None]  << return val of main()

# %%
pd.set_option("display.max.columns", None)

# %%
df = Globals.DATAFRAME_LIST[0]

# %%
df.head()
# Out:
#       symbol        date calendarYear period  currentRatio  quickRatio  \
# 0  601002.SS  2023-09-30         2023     Q3      3.780702    1.772534
# 1  601002.SS  2023-06-30         2023     Q2      3.227067    1.292858
# 2  601002.SS  2023-03-31         2023     Q1      3.461393    1.417210
# 3  601002.SS  2022-12-31         2022     Q4      3.614871    1.477061
# 4  601002.SS  2022-09-30         2022     Q3      3.296193    1.263237
#
#    cashRatio  daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# 0   0.261320              133.264308                  222.322334
# 1   0.117159              146.209782                  365.755397
# 2   0.127385              183.971976                  417.462039
# 3   0.141330              127.494380                  264.515396
# 4   0.159217              131.483644                  307.847390
#
#   operatingCycle  daysOfPayablesOutstanding cashConversionCycle  \
# 0     355.586642                  91.092896          264.493746
# 1     511.965179                 151.754945          360.210233
# 2     601.434016                 170.990885          430.443131
# 3     392.009776                  91.982792          300.026984
# 4     439.331034                 121.403205          317.927829
#
#    grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 0           0.120438              -0.025857           -0.029217
# 1           0.103366              -0.020300           -0.018237
# 2           0.203259               0.046186            0.045976
# 3           0.110885              -0.059100           -0.059283
# 4           0.131493               0.030077            0.013469
#
#    netProfitMargin  effectiveTaxRate returnOnAssets returnOnEquity  \
# 0        -0.022248          0.260029      -0.003012      -0.003703
# 1        -0.007911          0.594813      -0.000741      -0.000944
# 2         0.039291          0.130764       0.003557       0.004464
# 3         0.009993          1.171748       0.001252       0.001547
# 4         0.011670          0.131881       0.001413       0.001795
#
#   returnOnCapitalEmployed  netIncomePerEBT  ebtPerEbit  ebitPerRevenue  \
# 0               -0.004103         0.761454    1.129960       -0.025857
# 1                -0.00231         0.433781    0.898364       -0.020300
# 2                0.005007         0.854595    0.995443        0.046186
# 3               -0.008753        -0.168558    1.003094       -0.059100
# 4                0.004426         0.866473    0.447810        0.030077
#
#    debtRatio  debtEquityRatio  longTermDebtToCapitalization  \
# 0   0.006162         0.007576                           0.0
# 1   0.005915         0.007538                           0.0
# 2   0.011456         0.014379                           0.0
# 3   0.023483         0.029009                           0.0
# 4   0.016640         0.021140                           0.0
#
#    totalDebtToCapitalization  interestCoverage cashFlowToDebtRatio  \
# 0                   0.007519         -9.840727           -1.363799
# 1                   0.007482         -5.401210            4.694296
# 2                   0.014175          8.740869            0.310475
# 3                   0.028191        -15.399068            0.053311
# 4                   0.020702          7.752964            0.084912
#
#    companyEquityMultiplier  receivablesTurnover payablesTurnover  \
# 0                 1.229417             0.675350         0.988002
# 1                 1.274381             0.615554         0.593061
# 2                 1.255104             0.489205         0.526344
# 3                 1.235347             0.705913         0.978444
# 4                 1.270434             0.684496         0.741331
#
#   inventoryTurnover fixedAssetTurnover assetTurnover  \
# 0          0.404818           0.489236      0.135392
# 1          0.246066           0.348733      0.093664
# 2          0.215588            0.33414      0.090529
# 3          0.340245           0.445183       0.12528
# 4          0.292353           0.476912      0.121069
#
#   operatingCashFlowPerShare freeCashFlowPerShare  cashPerShare payoutRatio  \
# 0                       0.0                  0.0      0.000000   -3.435805
# 1                  0.154895             0.188512      0.427014   -0.091262
# 2                      0.02            -0.024242      0.274065    0.056029
# 3                  0.006885            -0.101232      0.275675    0.143008
# 4                  0.007984            -0.004165      0.265921    0.129996
#
#   operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                   -0.062073                            1.214717
# 1                    0.296461                            1.217034
# 2                    0.039291                           -1.212120
# 3                    0.009993                          -14.702851
# 4                     0.01167                           -0.521715
#
#   cashFlowCoverageRatios shortTermCoverageRatios  \
# 0              -1.363799               -1.363799
# 1               4.694296                4.694296
# 2               0.310475                0.310475
# 3               0.053311                0.053311
# 4               0.084912                0.084912
#
#    capitalExpenditureCoverageRatio  dividendPaidAndCapexCoverageRatio  \
# 0                         4.657288                          -0.983564
# 1                         4.607575                           4.556449
# 2                        -0.452055                          -0.463802
# 3                        -0.063683                          -0.064268
# 4                        -0.657153                          -0.718536
#
#   dividendPayoutRatio  priceBookValueRatio  priceToBookRatio  \
# 0                 NaN             0.000000          0.000000
# 1           -0.091262             1.133145          1.133145
# 2            0.056029             1.040182          1.040182
# 3            0.143008             1.042200          1.042200
# 4            0.129996             0.996006          0.996006
#
#    priceToSalesRatio  priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0           0.000000            0.000000                   0.000000
# 1           9.493201         -300.003551                  26.311264
# 2           9.154689           58.250000                -192.225230
# 3           6.734091          168.476935                 -45.835174
# 4           6.475526          138.718366               -1063.556033
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                        0.000000            0.000000
# 1                       32.021700           32.021700
# 2                      233.000000          233.000000
# 3                      673.907742          673.907742
# 4                      554.873464          554.873464
#
#    priceEarningsToGrowthRatio  priceSalesRatio dividendYield  \
# 0                    0.000000         0.000000           NaN
# 1                    2.489656         9.493201      0.000076
# 2                    0.306813         9.154689       0.00024
# 3                  -12.252868         6.734091      0.000212
# 4                   -1.663929         6.475526      0.000234
#
#    enterpriseValueMultiple  priceFairValue
# 0                -9.312307        0.000000
# 1              -688.842518        1.133145
# 2               110.555713        1.040182
# 3              -698.718645        1.042200
# 4               190.482578        0.996006

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
# %matplotlib inline

# %%
df.plot(x="date", y=["currentRatio", "quickRatio", "cashRatio"])
# Out:
# <Axes: xlabel='date'>

# %%
plt.plot(df["date"], df["cashPerShare"])

# %%
pe_ratio = df["priceEarningsRatio"]

# %%
pe_ratio.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_5 = df.sort_values(by="priceEarningsRatio", ascending=False).head()

# %%
top_5.plot(x="date", y="priceEarningsRatio", kind="bar", rot=5, fontsize=4)
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(x="ebtPerEbit", y="debtEquityRatio", kind="scatter")
# Out:
# <Axes: xlabel='ebtPerEbit', ylabel='debtEquityRatio'>

# %%
cat_totals = df.groupby("symbol")["daysOfSalesOutstanding"].sum().sort_values()

# %%
cat_totals.plot(kind="barh", fontsize=4)
# Out:
# <Axes: ylabel='symbol'>

# %%
df.tail()
# Out:
#      symbol        date calendarYear period  currentRatio  quickRatio  \
# 65  4540.TW  2022-06-30         2022     Q2      2.115101    0.969420
# 66  4540.TW  2022-03-31         2022     Q1      2.190144    0.980275
# 67  4540.TW  2021-12-31         2021     Q4      2.307091    1.080290
# 68  4540.TW  2021-09-30         2021     Q3      2.292218    1.265441
# 69  4540.TW  2021-06-30         2021     Q2      2.362925    1.359192
#
#     cashRatio  daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# 65   0.391820               95.143501                  252.790909
# 66   0.457195              106.758937                  360.176701
# 67   0.509422              103.981205                  287.192120
# 68   0.689989               93.702444                  233.952034
# 69   0.674460              113.875580                  225.026134
#
#    operatingCycle  daysOfPayablesOutstanding cashConversionCycle  \
# 65     347.934409                  59.453388          288.481022
# 66     466.935637                  90.434284          376.501353
# 67     391.173325                  99.836383          291.336942
# 68     327.654478                  96.313063          231.341415
# 69     338.901714                  99.111920          239.789794
#
#     grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 65           0.254645               0.125506            0.085555
# 66           0.315876               0.217999            0.174580
# 67           0.221974               0.081336            0.070982
# 68           0.285376               0.168828            0.158628
# 69           0.258265               0.121035            0.104329
#
#     netProfitMargin  effectiveTaxRate returnOnAssets returnOnEquity  \
# 65         0.054515          0.362806       0.006948       0.016419
# 66         0.124807          0.285098       0.012516       0.029109
# 67         0.056233          0.207776       0.006487       0.013607
# 68         0.116589          0.265016       0.016225       0.035368
# 69         0.080495          0.228452       0.010534       0.022794
#
#    returnOnCapitalEmployed  netIncomePerEBT  ebtPerEbit  ebitPerRevenue  \
# 65                0.020861         0.637194    0.681682        0.125506
# 66                0.028297         0.714902    0.800830        0.217999
# 67                0.012241         0.792224    0.872692        0.081336
# 68                  0.0314         0.734984    0.939588        0.168828
# 69                 0.02089         0.771548    0.861968        0.121035
#
#     debtRatio  debtEquityRatio  longTermDebtToCapitalization  \
# 65   0.449276         1.061723                      0.445348
# 66   0.451410         1.049869                      0.440267
# 67   0.374588         0.785677                      0.376231
# 68   0.385271         0.839844                      0.385659
# 69   0.382490         0.827708                      0.390488
#
#     totalDebtToCapitalization  interestCoverage cashFlowToDebtRatio  \
# 65                   0.514969          9.948172           -0.001202
# 66                   0.512164         17.586335           -0.042174
# 67                   0.439988          7.854971           -0.009796
# 68                   0.456476         20.089281            0.070023
# 69                   0.452867         13.759494             0.02653
#
#     companyEquityMultiplier  receivablesTurnover payablesTurnover  \
# 65                 2.363188             0.945940         1.513791
# 66                 2.325757             0.843021         0.995198
# 67                 2.097443             0.865541         0.901475
# 68                 2.179879             0.960487         0.934453
# 69                 2.163996             0.790336         0.908064
#
#    inventoryTurnover fixedAssetTurnover assetTurnover  \
# 65          0.356025           0.267743      0.127443
# 66          0.249877           0.212073      0.100283
# 67          0.313379           0.296814      0.115365
# 68          0.384694           0.366203      0.139162
# 69          0.399954           0.335802       0.13086
#
#    operatingCashFlowPerShare freeCashFlowPerShare  cashPerShare payoutRatio  \
# 65                  -0.04429            -0.697753      7.498116           0
# 66                 -1.580284            -9.910903      8.630646           0
# 67                 -0.311217            -1.198119     10.087405           0
# 68                  1.978669             1.202817     12.741779           0
# 69                  0.732156            -0.075312     11.767119           0
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 65                   -0.004236                           15.754169
# 66                   -0.189839                            6.271595
# 67                   -0.031808                            3.849782
# 68                    0.193859                            0.607892
# 69                    0.077546                           -0.102863
#
#    cashFlowCoverageRatios shortTermCoverageRatios  \
# 65              -0.001202                -0.00493
# 66              -0.042174                -0.16816
# 67              -0.009796               -0.042169
# 68               0.070023                0.277287
# 69                0.02653                0.117398
#
#     capitalExpenditureCoverageRatio  dividendPaidAndCapexCoverageRatio  \
# 65                         0.067777                           0.067777
# 66                         0.189696                           0.189696
# 67                         0.350904                           0.350904
# 68                        -2.550316                          -2.550316
# 69                        -0.906731                          -0.906731
#
#    dividendPayoutRatio  priceBookValueRatio  priceToBookRatio  \
# 65                   0             1.260195          1.260195
# 66                   0             1.263624          1.263624
# 67                   0             1.235303          1.235303
# 68                   0             1.377578          1.377578
# 69                   0             1.577617          1.577617
#
#     priceToSalesRatio  priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 65           4.184296           19.188597                 -62.701240
# 66           5.417859           10.852440                  -4.550544
# 67           5.105170           22.696386                 -41.690352
# 68           4.541108            9.737395                  38.534551
# 69           5.571074           17.302632                -698.429067
#
#     priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 65                     -987.805915         -987.805915
# 66                      -28.539171          -28.539171
# 67                     -160.498787         -160.498787
# 68                       23.424835           23.424835
# 69                       71.842586           71.842586
#
#     priceEarningsToGrowthRatio  priceSalesRatio dividendYield  \
# 65                   -0.424599         4.184296             0
# 66                    0.121813         5.417859             0
# 67                   -0.422011         5.105170             0
# 68                    0.172103         4.541108             0
# 69                    0.026216         5.571074             0
#
#     enterpriseValueMultiple  priceFairValue
# 65                36.049061        1.260195
# 66                29.222362        1.263624
# 67                49.493938        1.235303
# 68                25.141554        1.377578
# 69                39.470595        1.577617

# %%
df.groupby("symbol")["quickRatio"].count()
# Out:
# symbol
# 0413.HK      10
# 4540.TW      20
# 601002.SS    20
# 8270.HK      10
# HDGHF        10
# Name: quickRatio, dtype: int64

# %%
by_symbol = df.groupby("symbol")

# %%
for stock, frame in by_symbol:
    print(f"First 2 entries for {stock!r}")
    print("------------------------")
    print(frame.head(2), end="\n\n")
# Out:
# First 2 entries for '0413.HK'
# ------------------------
#                       symbol  currentRatio  quickRatio  cashRatio  \
# calendarYear period
# 2023         Q2      0413.HK      1.017325    0.133577   0.129775
# 2022         Q4      0413.HK      1.152338    0.162596   0.158132
#
#                      daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# calendarYear period
# 2023         Q2                         0.0                         0.0
# 2022         Q4                         0.0                         0.0
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# calendarYear period
# 2023         Q2                NaN                        0.0
# 2022         Q4                NaN                        0.0
#
#                     cashConversionCycle  grossProfitMargin  \
# calendarYear period
# 2023         Q2                     NaN                0.0
# 2022         Q4                     NaN                0.0
#
#                      operatingProfitMargin  pretaxProfitMargin  \
# calendarYear period
# 2023         Q2                        0.0                 0.0
# 2022         Q4                        0.0                 0.0
#
#                      netProfitMargin  effectiveTaxRate returnOnAssets  \
# calendarYear period
# 2023         Q2                  0.0               0.0            NaN
# 2022         Q4                  0.0               0.0            NaN
#
#                     returnOnEquity returnOnCapitalEmployed  netIncomePerEBT  \
# calendarYear period
# 2023         Q2                NaN                     NaN              0.0
# 2022         Q4                NaN                     NaN              0.0
#
#                      ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# calendarYear period
# 2023         Q2             0.0             0.0   0.319469         0.735418
# 2022         Q4             0.0             0.0   0.293320         0.644245
#
#                      longTermDebtToCapitalization  totalDebtToCapitalization  \
# calendarYear period
# 2023         Q2                          0.280199                   0.423770
# 2022         Q4                          0.294500                   0.391818
#
#                      interestCoverage cashFlowToDebtRatio  \
# calendarYear period
# 2023         Q2                   0.0                 NaN
# 2022         Q4                   0.0                 NaN
#
#                      companyEquityMultiplier  receivablesTurnover  \
# calendarYear period
# 2023         Q2                     2.301999                  0.0
# 2022         Q4                     2.196393                  0.0
#
#                     payablesTurnover inventoryTurnover fixedAssetTurnover  \
# calendarYear period
# 2023         Q2                  NaN               NaN                NaN
# 2022         Q4                  NaN               NaN                NaN
#
#                     assetTurnover operatingCashFlowPerShare  \
# calendarYear period
# 2023         Q2               NaN                       0.0
# 2022         Q4               NaN                       0.0
#
#                     freeCashFlowPerShare  cashPerShare payoutRatio  \
# calendarYear period
# 2023         Q2                      0.0           0.0           0
# 2022         Q4                      0.0           0.0           0
#
#                     operatingCashFlowSalesRatio  \
# calendarYear period
# 2023         Q2                             0.0
# 2022         Q4                             0.0
#
#                      freeCashFlowOperatingCashFlowRatio  \
# calendarYear period
# 2023         Q2                                     0.0
# 2022         Q4                                     0.0
#
#                     cashFlowCoverageRatios shortTermCoverageRatios  \
# calendarYear period
# 2023         Q2                        NaN                     NaN
# 2022         Q4                        NaN                     NaN
#
#                      capitalExpenditureCoverageRatio  \
# calendarYear period
# 2023         Q2                                  0.0
# 2022         Q4                                  0.0
#
#                      dividendPaidAndCapexCoverageRatio dividendPayoutRatio  \
# calendarYear period
# 2023         Q2                                    0.0                   0
# 2022         Q4                                    0.0                   0
#
#                      priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# calendarYear period
# 2023         Q2                      0.0               0.0                0.0
# 2022         Q4                      0.0               0.0                0.0
#
#                      priceEarningsRatio  priceToFreeCashFlowsRatio  \
# calendarYear period
# 2023         Q2                     0.0                        0.0
# 2022         Q4                     0.0                        0.0
#
#                      priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# calendarYear period
# 2023         Q2                                 0.0                 0.0
# 2022         Q4                                 0.0                 0.0
#
#                      priceEarningsToGrowthRatio  priceSalesRatio  \
# calendarYear period
# 2023         Q2                             0.0              0.0
# 2022         Q4                             0.0              0.0
#
#                     dividendYield  enterpriseValueMultiple  priceFairValue
# calendarYear period
# 2023         Q2               NaN                      0.0             0.0
# 2022         Q4               NaN                      0.0             0.0
#
# First 2 entries for '4540.TW'
# ------------------------
#                       symbol  currentRatio  quickRatio  cashRatio  \
# calendarYear period
# 2023         Q3      4540.TW      2.704175    1.041850   0.356179
#              Q2      4540.TW      2.491278    1.022781   0.422829
#
#                      daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# calendarYear period
# 2023         Q3                  154.100857                  465.010645
#              Q2                  127.565429                  391.083867
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# calendarYear period
# 2023         Q3         619.111502                  63.263050
#              Q2         518.649296                  77.954166
#
#                     cashConversionCycle  grossProfitMargin  \
# calendarYear period
# 2023         Q3              555.848453           0.197056
#              Q2               440.69513           0.201271
#
#                      operatingProfitMargin  pretaxProfitMargin  \
# calendarYear period
# 2023         Q3                   0.160562            0.070867
#              Q2                  -0.073825           -0.069264
#
#                      netProfitMargin  effectiveTaxRate returnOnAssets  \
# calendarYear period
# 2023         Q3             0.044551          0.371343       0.003438
#              Q2            -0.041482          0.401095      -0.003709
#
#                     returnOnEquity returnOnCapitalEmployed  netIncomePerEBT  \
# calendarYear period
# 2023         Q3           0.008246                0.015348         0.628657
#              Q2          -0.009154                -0.00837         0.598905
#
#                      ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# calendarYear period
# 2023         Q3        0.441367        0.160562   0.496822         1.191683
#              Q2        0.938210       -0.073825   0.472475         1.166224
#
#                      longTermDebtToCapitalization  totalDebtToCapitalization  \
# calendarYear period
# 2023         Q3                          0.482551                   0.543730
#              Q2                          0.485236                   0.538367
#
#                      interestCoverage cashFlowToDebtRatio  \
# calendarYear period
# 2023         Q3              5.259398           -0.028197
#              Q2             -3.118914           -0.018906
#
#                      companyEquityMultiplier  receivablesTurnover  \
# calendarYear period
# 2023         Q3                     2.398608             0.584033
#              Q2                     2.468328             0.705520
#
#                     payablesTurnover inventoryTurnover fixedAssetTurnover  \
# calendarYear period
# 2023         Q3             1.422631          0.193544            0.17187
#              Q2             1.154525           0.23013           0.202108
#
#                     assetTurnover operatingCashFlowPerShare  \
# calendarYear period
# 2023         Q3           0.07717                 -1.222425
#              Q2          0.089401                 -0.770776
#
#                     freeCashFlowPerShare  cashPerShare payoutRatio  \
# calendarYear period
# 2023         Q3                -1.706591      5.989814           0
#              Q2                -1.628052      7.726767           0
#
#                     operatingCashFlowSalesRatio  \
# calendarYear period
# 2023         Q3                       -0.181533
#              Q2                       -0.099918
#
#                      freeCashFlowOperatingCashFlowRatio  \
# calendarYear period
# 2023         Q3                                1.396071
#              Q2                                2.112224
#
#                     cashFlowCoverageRatios shortTermCoverageRatios  \
# calendarYear period
# 2023         Q3                  -0.028197               -0.129676
#              Q2                  -0.018906               -0.098615
#
#                      capitalExpenditureCoverageRatio  \
# calendarYear period
# 2023         Q3                             2.524803
#              Q2                             0.899100
#
#                      dividendPaidAndCapexCoverageRatio dividendPayoutRatio  \
# calendarYear period
# 2023         Q3                               2.524803                   0
#              Q2                               0.899100                   0
#
#                      priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# calendarYear period
# 2023         Q3                 0.889239          0.889239           4.804061
#              Q2                 1.145674          1.145674           5.191778
#
#                      priceEarningsRatio  priceToFreeCashFlowsRatio  \
# calendarYear period
# 2023         Q3               26.958333                 -18.955915
#              Q2              -31.289062                 -24.599957
#
#                      priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# calendarYear period
# 2023         Q3                          -26.463793          -26.463793
#              Q2                          -51.960614          -51.960614
#
#                      priceEarningsToGrowthRatio  priceSalesRatio  \
# calendarYear period
# 2023         Q3                        0.139140         4.804061
#              Q2                        0.179391         5.191778
#
#                     dividendYield  enterpriseValueMultiple  priceFairValue
# calendarYear period
# 2023         Q3                 0                36.887615        0.889239
#              Q2                 0               365.457561        1.145674
#
# First 2 entries for '601002.SS'
# ------------------------
#                         symbol  currentRatio  quickRatio  cashRatio  \
# calendarYear period
# 2023         Q3      601002.SS      3.780702    1.772534   0.261320
#              Q2      601002.SS      3.227067    1.292858   0.117159
#
#                      daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# calendarYear period
# 2023         Q3                  133.264308                  222.322334
#              Q2                  146.209782                  365.755397
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# calendarYear period
# 2023         Q3         355.586642                  91.092896
#              Q2         511.965179                 151.754945
#
#                     cashConversionCycle  grossProfitMargin  \
# calendarYear period
# 2023         Q3              264.493746           0.120438
#              Q2              360.210233           0.103366
#
#                      operatingProfitMargin  pretaxProfitMargin  \
# calendarYear period
# 2023         Q3                  -0.025857           -0.029217
#              Q2                  -0.020300           -0.018237
#
#                      netProfitMargin  effectiveTaxRate returnOnAssets  \
# calendarYear period
# 2023         Q3            -0.022248          0.260029      -0.003012
#              Q2            -0.007911          0.594813      -0.000741
#
#                     returnOnEquity returnOnCapitalEmployed  netIncomePerEBT  \
# calendarYear period
# 2023         Q3          -0.003703               -0.004103         0.761454
#              Q2          -0.000944                -0.00231         0.433781
#
#                      ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# calendarYear period
# 2023         Q3        1.129960       -0.025857   0.006162         0.007576
#              Q2        0.898364       -0.020300   0.005915         0.007538
#
#                      longTermDebtToCapitalization  totalDebtToCapitalization  \
# calendarYear period
# 2023         Q3                               0.0                   0.007519
#              Q2                               0.0                   0.007482
#
#                      interestCoverage cashFlowToDebtRatio  \
# calendarYear period
# 2023         Q3             -9.840727           -1.363799
#              Q2             -5.401210            4.694296
#
#                      companyEquityMultiplier  receivablesTurnover  \
# calendarYear period
# 2023         Q3                     1.229417             0.675350
#              Q2                     1.274381             0.615554
#
#                     payablesTurnover inventoryTurnover fixedAssetTurnover  \
# calendarYear period
# 2023         Q3             0.988002          0.404818           0.489236
#              Q2             0.593061          0.246066           0.348733
#
#                     assetTurnover operatingCashFlowPerShare  \
# calendarYear period
# 2023         Q3          0.135392                       0.0
#              Q2          0.093664                  0.154895
#
#                     freeCashFlowPerShare  cashPerShare payoutRatio  \
# calendarYear period
# 2023         Q3                      0.0      0.000000   -3.435805
#              Q2                 0.188512      0.427014   -0.091262
#
#                     operatingCashFlowSalesRatio  \
# calendarYear period
# 2023         Q3                       -0.062073
#              Q2                        0.296461
#
#                      freeCashFlowOperatingCashFlowRatio  \
# calendarYear period
# 2023         Q3                                1.214717
#              Q2                                1.217034
#
#                     cashFlowCoverageRatios shortTermCoverageRatios  \
# calendarYear period
# 2023         Q3                  -1.363799               -1.363799
#              Q2                   4.694296                4.694296
#
#                      capitalExpenditureCoverageRatio  \
# calendarYear period
# 2023         Q3                             4.657288
#              Q2                             4.607575
#
#                      dividendPaidAndCapexCoverageRatio dividendPayoutRatio  \
# calendarYear period
# 2023         Q3                              -0.983564                 NaN
#              Q2                               4.556449           -0.091262
#
#                      priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# calendarYear period
# 2023         Q3                 0.000000          0.000000           0.000000
#              Q2                 1.133145          1.133145           9.493201
#
#                      priceEarningsRatio  priceToFreeCashFlowsRatio  \
# calendarYear period
# 2023         Q3                0.000000                   0.000000
#              Q2             -300.003551                  26.311264
#
#                      priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# calendarYear period
# 2023         Q3                              0.0000              0.0000
#              Q2                             32.0217             32.0217
#
#                      priceEarningsToGrowthRatio  priceSalesRatio  \
# calendarYear period
# 2023         Q3                        0.000000         0.000000
#              Q2                        2.489656         9.493201
#
#                     dividendYield  enterpriseValueMultiple  priceFairValue
# calendarYear period
# 2023         Q3               NaN                -9.312307        0.000000
#              Q2          0.000076              -688.842518        1.133145
#
# First 2 entries for '8270.HK'
# ------------------------
#                       symbol  currentRatio  quickRatio  cashRatio  \
# calendarYear period
# 2023         Q3      8270.HK        0.0000    0.000000   0.000000
#              Q2      8270.HK        0.6583    0.532129   0.532129
#
#                      daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# calendarYear period
# 2023         Q3                         NaN                         NaN
#              Q2                         0.0                   24.826142
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# calendarYear period
# 2023         Q3                NaN                        NaN
#              Q2          24.826142                 306.710196
#
#                     cashConversionCycle  grossProfitMargin  \
# calendarYear period
# 2023         Q3                     NaN           0.079576
#              Q2             -281.884053           0.135776
#
#                      operatingProfitMargin  pretaxProfitMargin  \
# calendarYear period
# 2023         Q3                  -0.022632           -0.025326
#              Q2                  -0.174271           -0.177943
#
#                      netProfitMargin  effectiveTaxRate returnOnAssets  \
# calendarYear period
# 2023         Q3            -0.025313          0.000532            0.0
#              Q2            -0.178292         -0.007382      -0.015345
#
#                     returnOnEquity returnOnCapitalEmployed  netIncomePerEBT  \
# calendarYear period
# 2023         Q3                0.0                     0.0         0.999468
#              Q2          -0.043021               -0.039413         1.001958
#
#                      ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# calendarYear period
# 2023         Q3        1.119048       -0.022632     0.0000         0.000000
#              Q2        1.021074       -0.174271     0.0492         0.137938
#
#                      longTermDebtToCapitalization  totalDebtToCapitalization  \
# calendarYear period
# 2023         Q3                          0.000000                   0.000000
#              Q2                          0.017508                   0.121217
#
#                      interestCoverage cashFlowToDebtRatio  \
# calendarYear period
# 2023         Q3             -8.400000                 0.0
#              Q2            -47.452555                 NaN
#
#                      companyEquityMultiplier  receivablesTurnover  \
# calendarYear period
# 2023         Q3                     0.000000                  0.0
#              Q2                     2.803634                  0.0
#
#                     payablesTurnover inventoryTurnover fixedAssetTurnover  \
# calendarYear period
# 2023         Q3                  0.0               0.0                0.0
#              Q2             0.293437          3.625211           0.154849
#
#                     assetTurnover operatingCashFlowPerShare  \
# calendarYear period
# 2023         Q3               0.0                      None
#              Q2          0.086065                      None
#
#                     freeCashFlowPerShare  cashPerShare payoutRatio  \
# calendarYear period
# 2023         Q3                     None           NaN        None
#              Q2                     None      0.403682        None
#
#                     operatingCashFlowSalesRatio  \
# calendarYear period
# 2023         Q3                            None
#              Q2                            None
#
#                      freeCashFlowOperatingCashFlowRatio  \
# calendarYear period
# 2023         Q3                                     0.0
#              Q2                                     0.0
#
#                     cashFlowCoverageRatios shortTermCoverageRatios  \
# calendarYear period
# 2023         Q3                        0.0                     0.0
#              Q2                        NaN                     NaN
#
#                      capitalExpenditureCoverageRatio  \
# calendarYear period
# 2023         Q3                                  0.0
#              Q2                                  0.0
#
#                      dividendPaidAndCapexCoverageRatio dividendPayoutRatio  \
# calendarYear period
# 2023         Q3                                    0.0                None
#              Q2                                    0.0                None
#
#                      priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# calendarYear period
# 2023         Q3                 0.000000          0.000000           4.430753
#              Q2                 1.967484          1.967484           8.153845
#
#                      priceEarningsRatio  priceToFreeCashFlowsRatio  \
# calendarYear period
# 2023         Q3              -43.759874                        0.0
#              Q2              -11.433282                        0.0
#
#                      priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# calendarYear period
# 2023         Q3                                 0.0                 0.0
#              Q2                                 0.0                 0.0
#
#                      priceEarningsToGrowthRatio  priceSalesRatio  \
# calendarYear period
# 2023         Q3                       -0.587633         4.430753
#              Q2                        0.024342         8.153845
#
#                     dividendYield  enterpriseValueMultiple  priceFairValue
# calendarYear period
# 2023         Q3              None                      NaN        0.000000
#              Q2              None                -28.09153        1.967484
#
# First 2 entries for 'HDGHF'
# ------------------------
#                     symbol  currentRatio  quickRatio  cashRatio  \
# calendarYear period
# 2023         Q2      HDGHF      3.647478    1.628838   1.628838
# 2022         Q4      HDGHF      1.949517    0.520632   0.520632
#
#                      daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# calendarYear period
# 2023         Q2                         0.0                         0.0
# 2022         Q4                         0.0                         0.0
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# calendarYear period
# 2023         Q2               None                        0.0
# 2022         Q4               None                        0.0
#
#                     cashConversionCycle  grossProfitMargin  \
# calendarYear period
# 2023         Q2                    None                0.0
# 2022         Q4                    None                0.0
#
#                      operatingProfitMargin  pretaxProfitMargin  \
# calendarYear period
# 2023         Q2                        0.0                 0.0
# 2022         Q4                        0.0                 0.0
#
#                      netProfitMargin  effectiveTaxRate returnOnAssets  \
# calendarYear period
# 2023         Q2                  0.0               0.0           None
# 2022         Q4                  0.0               0.0           None
#
#                     returnOnEquity returnOnCapitalEmployed  netIncomePerEBT  \
# calendarYear period
# 2023         Q2               None                    None              0.0
# 2022         Q4               None                    None              0.0
#
#                      ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# calendarYear period
# 2023         Q2             0.0             0.0   0.083675         0.138813
# 2022         Q4             0.0             0.0   0.093480         0.191827
#
#                      longTermDebtToCapitalization  totalDebtToCapitalization  \
# calendarYear period
# 2023         Q2                          0.121031                   0.121893
# 2022         Q4                          0.159852                   0.160952
#
#                      interestCoverage cashFlowToDebtRatio  \
# calendarYear period
# 2023         Q2                   0.0                None
# 2022         Q4                   0.0                None
#
#                      companyEquityMultiplier  receivablesTurnover  \
# calendarYear period
# 2023         Q2                     1.658955                  0.0
# 2022         Q4                     2.052072                  0.0
#
#                     payablesTurnover inventoryTurnover fixedAssetTurnover  \
# calendarYear period
# 2023         Q2                 None              None               None
# 2022         Q4                 None              None               None
#
#                     assetTurnover operatingCashFlowPerShare  \
# calendarYear period
# 2023         Q2              None                         0
# 2022         Q4              None                         0
#
#                     freeCashFlowPerShare  cashPerShare payoutRatio  \
# calendarYear period
# 2023         Q2                        0           0.0           0
# 2022         Q4                        0           0.0           0
#
#                     operatingCashFlowSalesRatio  \
# calendarYear period
# 2023         Q2                               0
# 2022         Q4                               0
#
#                      freeCashFlowOperatingCashFlowRatio  \
# calendarYear period
# 2023         Q2                                     0.0
# 2022         Q4                                     0.0
#
#                     cashFlowCoverageRatios shortTermCoverageRatios  \
# calendarYear period
# 2023         Q2                       None                    None
# 2022         Q4                       None                    None
#
#                      capitalExpenditureCoverageRatio  \
# calendarYear period
# 2023         Q2                                  0.0
# 2022         Q4                                  0.0
#
#                      dividendPaidAndCapexCoverageRatio dividendPayoutRatio  \
# calendarYear period
# 2023         Q2                                    0.0                   0
# 2022         Q4                                    0.0                   0
#
#                      priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# calendarYear period
# 2023         Q2                      0.0               0.0                0.0
# 2022         Q4                      0.0               0.0                0.0
#
#                      priceEarningsRatio  priceToFreeCashFlowsRatio  \
# calendarYear period
# 2023         Q2                     0.0                        0.0
# 2022         Q4                     0.0                        0.0
#
#                      priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# calendarYear period
# 2023         Q2                                 0.0                 0.0
# 2022         Q4                                 0.0                 0.0
#
#                      priceEarningsToGrowthRatio  priceSalesRatio  \
# calendarYear period
# 2023         Q2                             0.0              0.0
# 2022         Q4                             0.0              0.0
#
#                     dividendYield  enterpriseValueMultiple  priceFairValue
# calendarYear period
# 2023         Q2              None                      0.0             0.0
# 2022         Q4              None                      0.0             0.0

# %%
# df.set_index(['calendarYear','period'], inplace=True)
df.groupby('symbol')['currentRatio'].plot(legend=True)
# Out:
# symbol
# 0413.HK      Axes(0.125,0.11;0.775x0.77)
# 4540.TW      Axes(0.125,0.11;0.775x0.77)
# 601002.SS    Axes(0.125,0.11;0.775x0.77)
# 8270.HK      Axes(0.125,0.11;0.775x0.77)
# HDGHF        Axes(0.125,0.11;0.775x0.77)
# Name: currentRatio, dtype: object

# %%
df.reset_index()
# Out:
#    calendarYear period     symbol  currentRatio  quickRatio  cashRatio  \
# 0          2023     Q3  601002.SS      3.780702    1.772534   0.261320
# 1          2023     Q2  601002.SS      3.227067    1.292858   0.117159
# 2          2023     Q1  601002.SS      3.461393    1.417210   0.127385
# 3          2022     Q4  601002.SS      3.614871    1.477061   0.141330
# 4          2022     Q3  601002.SS      3.296193    1.263237   0.159217
# ..          ...    ...        ...           ...         ...        ...
# 65         2022     Q2    4540.TW      2.115101    0.969420   0.391820
# 66         2022     Q1    4540.TW      2.190144    0.980275   0.457195
# 67         2021     Q4    4540.TW      2.307091    1.080290   0.509422
# 68         2021     Q3    4540.TW      2.292218    1.265441   0.689989
# 69         2021     Q2    4540.TW      2.362925    1.359192   0.674460
#
#     daysOfSalesOutstanding  daysOfInventoryOutstanding operatingCycle  \
# 0               133.264308                  222.322334     355.586642
# 1               146.209782                  365.755397     511.965179
# 2               183.971976                  417.462039     601.434016
# 3               127.494380                  264.515396     392.009776
# 4               131.483644                  307.847390     439.331034
# ..                     ...                         ...            ...
# 65               95.143501                  252.790909     347.934409
# 66              106.758937                  360.176701     466.935637
# 67              103.981205                  287.192120     391.173325
# 68               93.702444                  233.952034     327.654478
# 69              113.875580                  225.026134     338.901714
#
#     daysOfPayablesOutstanding cashConversionCycle  grossProfitMargin  \
# 0                   91.092896          264.493746           0.120438
# 1                  151.754945          360.210233           0.103366
# 2                  170.990885          430.443131           0.203259
# 3                   91.982792          300.026984           0.110885
# 4                  121.403205          317.927829           0.131493
# ..                        ...                 ...                ...
# 65                  59.453388          288.481022           0.254645
# 66                  90.434284          376.501353           0.315876
# 67                  99.836383          291.336942           0.221974
# 68                  96.313063          231.341415           0.285376
# 69                  99.111920          239.789794           0.258265
#
#     operatingProfitMargin  pretaxProfitMargin  netProfitMargin  \
# 0               -0.025857           -0.029217        -0.022248
# 1               -0.020300           -0.018237        -0.007911
# 2                0.046186            0.045976         0.039291
# 3               -0.059100           -0.059283         0.009993
# 4                0.030077            0.013469         0.011670
# ..                    ...                 ...              ...
# 65               0.125506            0.085555         0.054515
# 66               0.217999            0.174580         0.124807
# 67               0.081336            0.070982         0.056233
# 68               0.168828            0.158628         0.116589
# 69               0.121035            0.104329         0.080495
#
#     effectiveTaxRate returnOnAssets returnOnEquity returnOnCapitalEmployed  \
# 0           0.260029      -0.003012      -0.003703               -0.004103
# 1           0.594813      -0.000741      -0.000944                -0.00231
# 2           0.130764       0.003557       0.004464                0.005007
# 3           1.171748       0.001252       0.001547               -0.008753
# 4           0.131881       0.001413       0.001795                0.004426
# ..               ...            ...            ...                     ...
# 65          0.362806       0.006948       0.016419                0.020861
# 66          0.285098       0.012516       0.029109                0.028297
# 67          0.207776       0.006487       0.013607                0.012241
# 68          0.265016       0.016225       0.035368                  0.0314
# 69          0.228452       0.010534       0.022794                 0.02089
#
#     netIncomePerEBT  ebtPerEbit  ebitPerRevenue  debtRatio  debtEquityRatio  \
# 0          0.761454    1.129960       -0.025857   0.006162         0.007576
# 1          0.433781    0.898364       -0.020300   0.005915         0.007538
# 2          0.854595    0.995443        0.046186   0.011456         0.014379
# 3         -0.168558    1.003094       -0.059100   0.023483         0.029009
# 4          0.866473    0.447810        0.030077   0.016640         0.021140
# ..              ...         ...             ...        ...              ...
# 65         0.637194    0.681682        0.125506   0.449276         1.061723
# 66         0.714902    0.800830        0.217999   0.451410         1.049869
# 67         0.792224    0.872692        0.081336   0.374588         0.785677
# 68         0.734984    0.939588        0.168828   0.385271         0.839844
# 69         0.771548    0.861968        0.121035   0.382490         0.827708
#
#     longTermDebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                       0.000000                   0.007519         -9.840727
# 1                       0.000000                   0.007482         -5.401210
# 2                       0.000000                   0.014175          8.740869
# 3                       0.000000                   0.028191        -15.399068
# 4                       0.000000                   0.020702          7.752964
# ..                           ...                        ...               ...
# 65                      0.445348                   0.514969          9.948172
# 66                      0.440267                   0.512164         17.586335
# 67                      0.376231                   0.439988          7.854971
# 68                      0.385659                   0.456476         20.089281
# 69                      0.390488                   0.452867         13.759494
#
#    cashFlowToDebtRatio  companyEquityMultiplier  receivablesTurnover  \
# 0            -1.363799                 1.229417             0.675350
# 1             4.694296                 1.274381             0.615554
# 2             0.310475                 1.255104             0.489205
# 3             0.053311                 1.235347             0.705913
# 4             0.084912                 1.270434             0.684496
# ..                 ...                      ...                  ...
# 65           -0.001202                 2.363188             0.945940
# 66           -0.042174                 2.325757             0.843021
# 67           -0.009796                 2.097443             0.865541
# 68            0.070023                 2.179879             0.960487
# 69             0.02653                 2.163996             0.790336
#
#    payablesTurnover inventoryTurnover fixedAssetTurnover assetTurnover  \
# 0          0.988002          0.404818           0.489236      0.135392
# 1          0.593061          0.246066           0.348733      0.093664
# 2          0.526344          0.215588            0.33414      0.090529
# 3          0.978444          0.340245           0.445183       0.12528
# 4          0.741331          0.292353           0.476912      0.121069
# ..              ...               ...                ...           ...
# 65         1.513791          0.356025           0.267743      0.127443
# 66         0.995198          0.249877           0.212073      0.100283
# 67         0.901475          0.313379           0.296814      0.115365
# 68         0.934453          0.384694           0.366203      0.139162
# 69         0.908064          0.399954           0.335802       0.13086
#
#    operatingCashFlowPerShare freeCashFlowPerShare  cashPerShare payoutRatio  \
# 0                        0.0                  0.0      0.000000   -3.435805
# 1                   0.154895             0.188512      0.427014   -0.091262
# 2                       0.02            -0.024242      0.274065    0.056029
# 3                   0.006885            -0.101232      0.275675    0.143008
# 4                   0.007984            -0.004165      0.265921    0.129996
# ..                       ...                  ...           ...         ...
# 65                  -0.04429            -0.697753      7.498116           0
# 66                 -1.580284            -9.910903      8.630646           0
# 67                 -0.311217            -1.198119     10.087405           0
# 68                  1.978669             1.202817     12.741779           0
# 69                  0.732156            -0.075312     11.767119           0
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                    -0.062073                            1.214717
# 1                     0.296461                            1.217034
# 2                     0.039291                           -1.212120
# 3                     0.009993                          -14.702851
# 4                      0.01167                           -0.521715
# ..                         ...                                 ...
# 65                   -0.004236                           15.754169
# 66                   -0.189839                            6.271595
# 67                   -0.031808                            3.849782
# 68                    0.193859                            0.607892
# 69                    0.077546                           -0.102863
#
#    cashFlowCoverageRatios shortTermCoverageRatios  \
# 0               -1.363799               -1.363799
# 1                4.694296                4.694296
# 2                0.310475                0.310475
# 3                0.053311                0.053311
# 4                0.084912                0.084912
# ..                    ...                     ...
# 65              -0.001202                -0.00493
# 66              -0.042174                -0.16816
# 67              -0.009796               -0.042169
# 68               0.070023                0.277287
# 69                0.02653                0.117398
#
#     capitalExpenditureCoverageRatio  dividendPaidAndCapexCoverageRatio  \
# 0                          4.657288                          -0.983564
# 1                          4.607575                           4.556449
# 2                         -0.452055                          -0.463802
# 3                         -0.063683                          -0.064268
# 4                         -0.657153                          -0.718536
# ..                              ...                                ...
# 65                         0.067777                           0.067777
# 66                         0.189696                           0.189696
# 67                         0.350904                           0.350904
# 68                        -2.550316                          -2.550316
# 69                        -0.906731                          -0.906731
#
#    dividendPayoutRatio  priceBookValueRatio  priceToBookRatio  \
# 0                  NaN             0.000000          0.000000
# 1            -0.091262             1.133145          1.133145
# 2             0.056029             1.040182          1.040182
# 3             0.143008             1.042200          1.042200
# 4             0.129996             0.996006          0.996006
# ..                 ...                  ...               ...
# 65                   0             1.260195          1.260195
# 66                   0             1.263624          1.263624
# 67                   0             1.235303          1.235303
# 68                   0             1.377578          1.377578
# 69                   0             1.577617          1.577617
#
#     priceToSalesRatio  priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0            0.000000            0.000000                   0.000000
# 1            9.493201         -300.003551                  26.311264
# 2            9.154689           58.250000                -192.225230
# 3            6.734091          168.476935                 -45.835174
# 4            6.475526          138.718366               -1063.556033
# ..                ...                 ...                        ...
# 65           4.184296           19.188597                 -62.701240
# 66           5.417859           10.852440                  -4.550544
# 67           5.105170           22.696386                 -41.690352
# 68           4.541108            9.737395                  38.534551
# 69           5.571074           17.302632                -698.429067
#
#     priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                         0.000000            0.000000
# 1                        32.021700           32.021700
# 2                       233.000000          233.000000
# 3                       673.907742          673.907742
# 4                       554.873464          554.873464
# ..                             ...                 ...
# 65                     -987.805915         -987.805915
# 66                      -28.539171          -28.539171
# 67                     -160.498787         -160.498787
# 68                       23.424835           23.424835
# 69                       71.842586           71.842586
#
#     priceEarningsToGrowthRatio  priceSalesRatio dividendYield  \
# 0                     0.000000         0.000000           NaN
# 1                     2.489656         9.493201      0.000076
# 2                     0.306813         9.154689       0.00024
# 3                   -12.252868         6.734091      0.000212
# 4                    -1.663929         6.475526      0.000234
# ..                         ...              ...           ...
# 65                   -0.424599         4.184296             0
# 66                    0.121813         5.417859             0
# 67                   -0.422011         5.105170             0
# 68                    0.172103         4.541108             0
# 69                    0.026216         5.571074             0
#
#     enterpriseValueMultiple  priceFairValue
# 0                 -9.312307        0.000000
# 1               -688.842518        1.133145
# 2                110.555713        1.040182
# 3               -698.718645        1.042200
# 4                190.482578        0.996006
# ..                      ...             ...
# 65                36.049061        1.260195
# 66                29.222362        1.263624
# 67                49.493938        1.235303
# 68                25.141554        1.377578
# 69                39.470595        1.577617
#
# [70 rows x 57 columns]

# %%
df1 = Globals.DATAFRAME_LIST[1]
df1.head()
# Out:
#          date     symbol reportedCurrency         cik fillingDate  \
# 0  2023-09-30  601002.SS              CNY  0000000000  2023-09-30
# 1  2023-06-30  601002.SS              CNY  0000000000  2023-06-30
# 2  2023-03-31  601002.SS              CNY  0000000000  2023-03-31
# 3  2022-12-31  601002.SS              CNY  0000000000  2022-12-31
# 4  2022-09-30  601002.SS              CNY  0000000000  2022-09-30
#
#           acceptedDate calendarYear period       revenue  costOfRevenue  \
# 0  2023-09-29 20:00:00         2023     Q3  6.934089e+08   6.098959e+08
# 1  2023-06-29 20:00:00         2023     Q2  4.994758e+08   4.478468e+08
# 2  2023-03-30 20:00:00         2023     Q1  4.866175e+08   3.877082e+08
# 3  2022-12-30 19:00:00         2022     Q4  6.595417e+08   5.864082e+08
# 4  2022-09-29 20:00:00         2022     Q3  6.548301e+08   5.687246e+08
#
#    grossProfit  grossProfitRatio  researchAndDevelopmentExpenses  \
# 0  83512951.19          0.120438                     36012244.06
# 1  51628979.65          0.103366                     27859549.15
# 2  98909279.53          0.203259                     17140457.91
# 3  73133528.76          0.110885                     34554170.09
# 4  86105560.09          0.131493                     25927321.46
#
#    generalAndAdministrativeExpenses  sellingAndMarketingExpenses  \
# 0                       49558283.08                  15061988.37
# 1                       -4850083.38                  10652193.95
# 2                       23599332.41                  16424326.14
# 3                      -40187231.17                  22048736.89
# 4                       57418592.70                  16677237.76
#
#    sellingGeneralAndAdministrativeExpenses  otherExpenses  operatingExpenses  \
# 0                              64620271.45    -2330099.14        64146136.80
# 1                               5802110.57     1030539.39        64758690.01
# 2                              40023658.55     1090222.74        58254339.20
# 3                             -18138494.28    64142787.87        80558463.68
# 4                              74095830.46   -32629267.82        67393884.10
#
#    costAndExpenses  interestIncome  interestExpense  \
# 0     6.740420e+08     -1663331.14       1821957.98
# 1     5.126055e+08       835193.97       1877270.84
# 2     4.459625e+08      -291887.02       2571249.31
# 3     6.669666e+08      1668415.19       2531246.36
# 4     6.361185e+08      -903752.09       2540347.78
#
#    depreciationAndAmortization       ebitda  ebitdaratio  operatingIncome  \
# 0                  35633841.08  17704449.23     0.025532     -17929391.85
# 1                   3370724.05  -6768809.07    -0.013552     -10139533.12
# 2                  17355227.07  39830181.58     0.081851      22474954.51
# 3                  32609473.06  -6369362.77    -0.009657     -38978835.83
# 4                   2237027.48  21932252.16     0.033493      19695224.68
#
#    operatingIncomeRatio  totalOtherIncomeExpensesNet  incomeBeforeTax  \
# 0             -0.025857                  -2330099.14     -20259490.99
# 1             -0.020300                   1030539.39      -9108993.73
# 2              0.046186                   -102423.49      22372531.02
# 3             -0.059100                   -120604.02     -39099439.85
# 4              0.030077                 -10875508.95       8819715.73
#
#    incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0             -0.029217       -5268058.84 -15426674.20       -0.022248
# 1             -0.018237       -5418145.53  -3951306.26       -0.007911
# 2              0.045976        2925522.43  19119450.12        0.039291
# 3             -0.059283      -45814691.94   6590536.38        0.009993
# 4              0.013469        1163150.95   7642048.15        0.011670
#
#       eps  epsdiluted  weightedAverageShsOut  weightedAverageShsOutDil link  \
# 0  0.0000      0.0000                      0                         0
# 1 -0.0041     -0.0041              955972506                 955972506
# 2  0.0200      0.0200              955972506                 955972506
# 3  0.0069      0.0069              957201183                 957201183
# 4  0.0080      0.0080              957194070                 957194070
#
#   finalLink
# 0
# 1
# 2
# 3
# 4
